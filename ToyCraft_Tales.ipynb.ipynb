# %%
df = pd.read_csv("sales.csv")
df.head()
# Out:
#          Date Product     Category  Sales  Profit
# 0  2024-01-01   Phone  Electronics  50000    8000
# 1  2024-01-02  Laptop  Electronics  70000   12000
# 2  2024-01-03   Shirt     Clothing  15000    3000
# 3  2024-01-04   Shoes     Clothing  20000    4000
# 4  2024-01-05   Watch  Accessories  10000    2000

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year

# %%
df['Month'] = df['Date'].dt.month

# %%
df['Profit_Margin'] = df['Profit'] / df['Sales']

# %%
df.head()
# Out:
#         Date Product     Category  Sales  Profit  Year  Month  Profit_Margin
# 0 2024-01-01   Phone  Electronics  50000    8000  2024      1       0.160000
# 1 2024-01-02  Laptop  Electronics  70000   12000  2024      1       0.171429
# 2 2024-01-03   Shirt     Clothing  15000    3000  2024      1       0.200000
# 3 2024-01-04   Shoes     Clothing  20000    4000  2024      1       0.200000
# 4 2024-01-05   Watch  Accessories  10000    2000  2024      1       0.200000

# %%
df.shape
# Out:
# (5, 8)

# %%
df['Sales'].sum()
# Out:
# np.int64(165000)

# %%
df['Profit'].sum()
# Out:
# np.int64(29000)

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Accessories     10000
# Clothing        35000
# Electronics    120000
# Name: Sales, dtype: int64

# %%
df.groupby('Category')['Profit'].sum()
# Out:
# Category
# Accessories     2000
# Clothing        7000
# Electronics    20000
# Name: Profit, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('Category')['Sales'].sum().plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
df.to_csv("cleaned_toycraft_sales.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\P SUDARSHAN'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\P SUDARSHAN'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.cache',
#  '.conda',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.vscode',
#  'anaconda3',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'cleaned_toycraft_sales.csv',
#  'Contacts',
#  'Cookies',
#  'Data_Visualization.ipynb',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'sales.csv',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Sentiment_Analysis.ipynb',
#  'Start Menu',
#  'Templates',
#  'ToyCraft_Tales.ipynb.ipynb',
#  'untitled.txt',
#  'Videos']
